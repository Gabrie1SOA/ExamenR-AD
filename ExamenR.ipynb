# %%
import pandas as pd
from pymongo import MongoClient

# %%
database= MongoClient("mongodb://localhost:27017")

# %%
import pymongo

myclient = pymongo.MongoClient("mongodb://localhost:27017")
mydb = myclient["ExamenR"]
                #cambiar a la coleccion deseada
mycol_consolidado = mydb["tokyo2021"]
df_consolidado=pd.DataFrame(list(mycol_consolidado.find()))
df_consolidado
# Out:
#                          _id                     Country  Gold Medal  \
# 0   66c4b46ce609867c54811706    United States of America          39
# 1   66c4b46ce609867c54811707  People's Republic of China          38
# 2   66c4b46ce609867c54811708                       Japan          27
# 3   66c4b46ce609867c54811709               Great Britain          22
# 4   66c4b46ce609867c5481170a                         ROC          20
# ..                       ...                         ...         ...
# 88  66c4b46ce609867c5481175e                       Ghana           0
# 89  66c4b46ce609867c5481175f                     Grenada           0
# 90  66c4b46ce609867c54811760                      Kuwait           0
# 91  66c4b46ce609867c54811761         Republic of Moldova           0
# 92  66c4b46ce609867c54811762        Syrian Arab Republic           0
#
#     Silver Medal  Bronze Medal  Total  Rank By Total
# 0             41            33    113              1
# ...

# %%
df_consolidado = df_consolidado.replace(',', '', regex=True)
df_consolidado = df_consolidado.replace("'", "", regex=True)
                       #cambiar nombre
df_consolidado.to_csv('Tokyo21.csv', index=False, encoding='utf-8',sep=';')
